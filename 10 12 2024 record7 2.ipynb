# %%
from ksb import rectangle1
from ksb import circle2
from ksb.XYZ import cuboid
from ksb.XYZ import sphere


while(1):
    print("1.Rectangle\n2.Circle\n3.Cuboid\n4.Sphere\n5.Exit")
    ch=int(input("Enter your choice:"))
    if ch==1:
        l=int(input("Enter length:"))
        b=int(input("Enter breadth:"))
        rectangle1.rectarea(l,b)
        rectangle1.rectperi(l,b)
    elif ch==2:
        r=int(input("Enter radius:"))
        circle2.circlearea(r)
        circle2.circleperi(r)
    elif ch==3:
        l=int(input("Enter length :"))
        b=int(input("Enter breadth :"))
        h=int(input("Enter height :"))
        cuboid.cuboidarea(l,b,h)
        cuboid.cuboidperi(l,b,h)
    elif ch==4:
            r=int(input("Enter radius:"))
            sphere.spherearea(r)
            sphere.sphereperi(r) 
    else:
            print("Existing....")
            break
# Out:
# 1.Rectangle
# 2.Circle
# 3.Cuboid
# 4.Sphere
# 5.Exit
# Enter your choice:1
# Enter length:5
# Enter breadth:4
# Area of rectangle: 20
# Perimeter of rectangle: 18
# 1.Rectangle
# 2.Circle
# 3.Cuboid
# 4.Sphere
# 5.Exit
# Enter your choice:2
# Enter radius:5
# Area of Circle: 78.5
# Perimeter of circle: 31.400000000000002
# 1.Rectangle
# 2.Circle
# 3.Cuboid
# 4.Sphere
# 5.Exit
# Enter your choice:3
# Enter length :4
# Enter breadth :5
# Enter height :5
# Area of cuboid : 130
# Perimeter of cuboid : 56
# 1.Rectangle
# 2.Circle
# 3.Cuboid
# 4.Sphere
# 5.Exit
# Enter your choice:4
# Enter radius:3
# Area of sphere: 56.519999999999996
# Perimeter of sphere: 113.04
# 1.Rectangle
# 2.Circle
# 3.Cuboid
# 4.Sphere
# 5.Exit
# Enter your choice:3
# Enter length :5
# Enter breadth :6
# Enter height :7
# Area of cuboid : 214
# Perimeter of cuboid : 72
# 1.Rectangle
# 2.Circle
# 3.Cuboid
# 4.Sphere
# 5.Exit
# Enter your choice:5
# Existing....
